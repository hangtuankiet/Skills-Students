# %%
# Đọc 7 Tổ hợp dữ liệu

# %%
import pandas as pd

# Load the data to see its structure and content
data_path = '../Data/raw/Data_Collect.csv'
data = pd.read_csv(data_path)

data.head()
# Out:
#                              Kỹ năng  \
# 0  Kỹ năng tranh luận Lập luận Logic
# 1     Kỹ năng tranh luận Thuyết Phục
# 2       Kỹ năng tranh luận Phản Biện
# 3          Kỹ năng kiểm soát cảm xúc
# 4          Kỹ năng Quản Lý Thời Gian
#
#    Trình bày luận điểm một cách có hệ thống rõ ràng  \
# 0                                                 1
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
#
#    Sử dụng dẫn chứng thống kê đáng tin cậy  \
# 0                                        1
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    Chủ động đưa ra các ví dụ trường hợp cụ thể để minh họa cho luận điểm  \
# 0                                                  1
# ...

# %%
# Tạo lại các tổ hợp từ 1 đến 4 biểu hiện không có mặt
combined_data_v2 = []  # Danh sách mới để chứa các tổ hợp

# Tạo các tổ hợp mới bao gồm cả tổ hợp với 4 biểu hiện không có mặt
for r in range(1, 5):  # Bây giờ bao gồm cả tổ hợp với 4 biểu hiện
    for combo in combinations(sample_columns, r):
        # Tạo một bản sao của bộ dữ liệu để không làm thay đổi bộ dữ liệu gốc
        temp_data = data.copy()
        
        # Đặt giá trị của các cột trong tổ hợp thành 0
        for col in combo:
            temp_data[col] = 0
        
        # Thêm vào danh sách kết quả mới
        combined_data_v2.append(temp_data)

# Tạo một DataFrame mới để chứa tất cả các tổ hợp mới
all_combinations_df_v2 = pd.DataFrame()

# Lặp qua tất cả các tổ hợp mới và gộp chúng lại
for i, df in enumerate(combined_data_v2):
    # Gộp với DataFrame tổng
    all_combinations_df_v2 = pd.concat([all_combinations_df_v2, df], ignore_index=True)

# Xuất kết quả ra một file CSV duy nhất
final_output_path_v2 = '../Data/raw/all_combinations_including_4.csv'
all_combinations_df_v2.to_csv(final_output_path_v2, index=False)

final_output_path_v2
# Out:
# './Data/raw/all_combinations_including_4.csv'

# %%
print(sample_columns)
# Out:
# Index(['Trình bày luận điểm một cách có hệ thống rõ ràng',
#        'Sử dụng dẫn chứng thống kê đáng tin cậy',
#        'Chủ động đưa ra các ví dụ trường hợp cụ thể để minh họa cho luận điểm',
#        'Có khả năng tóm tắt vấn đề một cách rõ ràng ngắn gọn',
#        'Sử dụng ngôn ngữ rõ ràng logic và lập luận chặt chẽ',
#        'Có khả năng điều chỉnh quan điểm dựa trên lập luận và bằng chứng mới'],
#       dtype='object')
